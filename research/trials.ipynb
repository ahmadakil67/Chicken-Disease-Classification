# %%
import yaml

yaml_file_path = 'test.yaml'

with open(yaml_file_path, "r") as f:
    data = yaml.safe_load(f)


print(data)
print(type(data))
# Out:
# {'name': 'Akil', 'age': 25, 'city': 'Sylhet', 'country': 'Bangladesh'}
# <class 'dict'>

# %%
data['name']
# Out:
# 'Akil'

# %%
data.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %% [markdown]
# # Configbox

# %%
from box import ConfigBox

d = ConfigBox(data)
d
# Out:
# ConfigBox({'name': 'Akil', 'age': 25, 'city': 'Sylhet', 'country': 'Bangladesh'})

# %%
d.name
d.age
# Out:
# 25

# %% [markdown]
# ## Ensure Annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int):
    return x*y
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_product(x=2,y="4")
#
# File c:\Users\feroz\miniconda3\envs\cnncls\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x00000296F66025E0> does not match annotation type <class 'int'>

# %%
import os
from dotenv import load_dotenv
from azure.storage.blob import BlobServiceClient

load_dotenv()

def download_from_azure(container_name, blob_name, download_path):
    connection_string = os.getenv(
        "AZURE_STORAGE_CONNECTION_STRING"
    )

    blob_service_client = BlobServiceClient.from_connection_string(
        connection_string
    )

    blob_client = blob_service_client.get_blob_client(
        container=container_name,
        blob=blob_name
    )

    print(f"Downloading {blob_name}...")

    with open(download_path, "wb") as f:
        data = blob_client.download_blob()
        data.readinto(f)

    print("Download complete ✅")


download_from_azure(
    container_name="chicken-data-2025",
    blob_name="data.zip",
    download_path="data.zip"
)
# Out:
# Downloading data.zip...
# Download complete ✅

# %%
# %pip install azure-storage-blob python-dotenv
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.26.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: python-dotenv in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (1.0.1)
# Collecting azure-core>=1.30.0 (from azure-storage-blob)
#   Downloading azure_core-1.33.0-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from azure-storage-blob) (47.0.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from azure-storage-blob) (4.13.2)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\feroz\miniconda3\envs\cnncls\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2026.7.22)
# Downloading azure_storage_blob-12.26.0-py3-none-any.whl (412 kB)
# Downloading azure_core-1.33.0-py3-none-any.whl (207 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.33.0 azure-storage-blob-12.26.0 isodate-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.storage.blob import BlobServiceClient
# Out:
# c:\Users\feroz\miniconda3\envs\cnncls\lib\site-packages\azure\storage\blob\_encryption.py:22: CryptographyDeprecationWarning: Python 3.8 is no longer supported by the Python core team and support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.8.
#   from cryptography.hazmat.backends import default_backend
